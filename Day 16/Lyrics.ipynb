# %%
#Make it Stop!
#Whoops. You made an accidental infinite loop...and nightmare. Introducing..."while True"...to make it stop.

#Can you guess the lyrics to my favorite song 🎶 🎤?  Day 16 of #Replit100DaysOfCode #100DaysOfCode. Join me on @Replit https://join.replit.com/python


print("👉 Day 16 Challenge")

'''while True:
  print("This program is running")
  goAgain = input("Go again?: ")
  if goAgain == "no":
    break
print("Aww, I was having a good time 😭")

print
counter = 0
while True:
  answer = int(input("Enter a number: "))
  print("Adding it up!")
  counter += answer
  print("Current total is", counter)
  addAnother = input("Add another? ")
  if addAnother == "no":
    break
  print("Bye!") '''


'''while True:
  color = input("Enter a color: ")
  if color == "red":
     break
  else:
    print("Cool color!")
    print("I don't like red")

print()
print("Fill in the blank lyrics!(Type in the blank lyrics and see if you are as cool as me.)")

count = 0
while True:
  print("Never going to ______ you up.")
  lyrics = input("Complete the song lyrics: ")
  if lyrics == "give":
    print("Well done! It only took you" ,count , "attempts.")
    break
  else:
    print("Try again!")
    count += 1
    if count == 3:
      print("You suck!")
      break
  
print("")'''
  
count = 0
while True:
  print(""" .... He said, One day, you'll leave this .... behind
          So live a life you will remember
   
          My father told me when I was just a child 👶
          These are the nights 🌚 that never die ....""")
  print()
  Lyrics = input("Complete the lyrics of the song : ")
  print()
  if Lyrics == "world":
    print("""Ohh! Nice,You complete the lyrics of the  song 🤩 it 
    take you,count,"attempts to complete the lyrics of the song""")
    break  
  else:
    print("You missed it 😌. Try again")
    count+=1
    print(count)
  print()

 






#replit100DaysOfCode
