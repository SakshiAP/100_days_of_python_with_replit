# %%
# Casting Spells on Your Code

# Teach the computer to recognize numbers (and do the math) with the 'magic' of int and float!

# Felt like I was at Hogwarts with all the casting I did today 🏰🧙 ! Day 9 of #Replit100DaysOfCode #100DaysOfCode. Join me on @Replit https://join.replit.com/python 


# Day 9 :Casting Spells on Your Code
print("👉 Day 9 Challenge")
print()
print("Generation Identifier")
print()
# Teach the computer to recognize numbers (and do the math) with the 'magic' of int and float!

#CHALLENGE : GENERATION IDENTIFIER

year = int(input("Which year were you born?: "))

if 1883<=year<=1900:
  print("It's lost generation 😔")
elif 1901<=year<=1927:
  print("Greatest generation🤩")
elif 1928<=year<=1945:
  print("Silent generation")
elif 1946<=year<=1964:
  print("Baby Boomers")
elif 1965<=year<=1980:
  print("Generation X")
elif 1981<=year<=1996:
  print("Millennials")
elif 1997<=year<=2012:
  print(" Generation Z")
elif 2012<=year<=2023:
  print("Generation Alpha")
else:
  print("Please enter valid year and Try again")

# string to integer converion
#myscore = int(input("Your score: "))
#if myscore == 100000:
 # print("Winner")
#else:
 # print("try again!")

# string to float conversion
#myPi = float(input("what is Pito 3dp to :"))

#if myPi == 3.14:
  #print("Exactly!")
#else:
 # print("Try again")

# Try and fix my code

#score = int(input("What was your score on the test?"))
#if score >80:
 # print("Not too shabby")
#elif score >70:
 # print("Acceptable.")
#else:
 # print("Dude, you need to study more!")


#replitDaysOfCode
