# %%
# Let's Cheat Continue

# Learn the `continue` command. An ideal component of building games AND build your first game that keeps score!

#New and improved 🪨 📄✂ game! Day 17 of #Replit100DaysOfCode #100DaysOfCode. Join me on @Replit https://join.replit.com/python

''' while True:
  print("You are in a corridor, do you go left or right?")
  direction = input("> ")
  if direction == "left":
    print("You have fallen to your death")
    break
  elif direction == "right":
    continue
  else:
    print("Ahh! You're a genius, you've won")
    exit()
    print("The game is over, you've failed!") '''

'''print()

print("Let's play chutes and ladders. Pick ladder or chute.")
while True:
  print("Do you want to go up the ladder or down the chute?")
  direction = input("> ")
  if direction == "chute":
    print("Game over!")
    break
  elif direction == "ladder":
    continue
  else:
    print("Game over!")
    exit() 
print("Thanks for playing!") '''

print()

print("👉 Day 7 Challenge")
print("")
print("🗻 📃 ✂  Rock Paper Scissor  🗻 📃 ✂ ")
print("")

count1 = 0
count2 = 0

while True:
  player_1 = input("Player 1 :")
  player_2 = input("Player 2 :")
  
  if player_1 == "R":
    if player_2 == "R":
      print("Draw 🗻 x 🗻")
    elif player_2 == "P":
      print("Player 2 Wins")
      count2 += 1
    elif player_2 == "S":
      print("Player 1 Wins 🗻 x ✂")
      count1 += 1
    else:
      print("Invalid move by player 2")
  elif player_1 == "P":
    if player_2 == "R":
      print("Player 1 Wins  📃 x 🗻")
      count1 += 1
    elif player_2 == "P":
      print("Draw  📃 x  📃")
    elif player_2 == "S":
      print("Player 2 Wins 📃 x ✂")
      count2 += 1
    else:
      print("Invalid move by player 2")
  
  elif player_1 =="S":
    if player_2 == "R":
      print("Player 2 Wins ✂ x 🗻")
      count2 += 1
    elif player_2 == "P":
      print("Player 1 Wins ✂ x 📃")
      count1 += 1
    elif player_2 == "S":
      print("Draw ✂ x ✂")
    else:
      print("Invalid move by player 2")
  else:
    print("Invalid move by player 1")
  print("Player 1 win :",count1)
  print("Player 2 win :",count2)

  if count1 == 3 or count2 == 3:
    print("Game over")
    exit()
  else:
    continue
  
   
#replit100DaysOfCode
